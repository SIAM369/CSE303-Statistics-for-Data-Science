# %% [markdown]
# # Assignment for Dataset
# ## Its all about collecting and describing datasets!

# %% [markdown]
# ### The key tasks are:
# * Collect extensive information regarding available dataset within your domain
# * Summarize those datasets in pictorial tree, short description and data summary.
#
# Please workthrough this notebook to complete your assignment. You may add additional markdown and code cells in jupyter notebook.

# %% [markdown]
# ### 1. Find all available public datasets within your topic. List the name of those datasets along with their URLs. Use a table to summarise the info. Also download each datasets and save them in google drive. We will try to find any other dataset that you could not find. For each of such unexplored dataset, you will loose 25% marks.

# %% [markdown]
# A. https://www.kaggle.com/datasets/caesarmario/application-data
#
# B. https://www.kaggle.com/datasets/rikdifos/credit-card-approval-prediction
#
# C. https://www.kaggle.com/datasets/samuelcortinhas/credit-card-approval-clean-data
#
# D. https://www.kaggle.com/datasets/laotse/credit-card-approval
#
# E. https://www.kaggle.com/datasets/alexisbcook/synthetic-credit-card-approval

# %% [markdown]
# ### 2. Write short descriptions of each dataset. Explain the meaining of each features (columns). Write short summary of each datasets. Write anyother information you may find relavent, including pictorial tree.

# %% [markdown]
# Your findings in this cell:
# A  :
#  Summary:  The dataset of a credit card application was viewed 10724 , downloaded 1547 on Kaggle. The Range Index 25128, entries 0 to 25127. There are total 21 columns on the dataset
#  Features name with description:
# 1.	Applicant ID:   Unique id of users
# 2.	Applicant Gender:  Male or female
# 3.	Owned Car:  Numbers of cars or not
# 4.	Owned Realty:  Alive or dead status of users
# 5.	Total Children: Number of children for nominee of users
# 6.	Total Income: Amount of income yearly or monthly
# 7.	Education Type: Academic background
# 8.	Family Status:  Financial situation of users
# 9.	Housing Type: Living address of users
# 10.	 Owned Mobile Phone: Users personal contact
# 11.	  Owned Work Phone: Users professional contact
# 12.	  Owned Phone: Cellphone information of users
# 13.	  Owned Email:  personal mail information
# 14.	  Job Title: workplace details
# 15.	  Total Family Members: family information
# 16.	 Applicant Age: Date of Birth information
# 17.	 Years of Working: Beginning day with credit account
# 18.	  Total Bad Debt: lowest amount of cash in.
# 19.	   Total Good Debt: highest amount of cash in.
# 20.	Status: Marital status of users.
#
#
#
#
# B: Summary: The dataset of a credit card application was viewed 358662 , downloaded 39326 and download per view ratio 0.11 on Kaggle. The Range Index 1048575, entries 0 to 1048574. There are total 3 columns on the first dataset. On the second dataset The Range Index 438557, entries 0 to 438556. There are total 18 columns
#
# Features name with description
#
#  1   CODE GENDER:
#  2   FLAG OWN CAR:
#  3   FLAG_OWN_REALTY
#  4   CNT_CHILDREN
#  5   AMT_INCOME_TOTAL
#  6   NAME_INCOME_TYPE
#  7   NAME_EDUCATION_TYPE
#  8   NAME_FAMILY_STATUS
#  9   NAME_HOUSING_TYPE
#  10  DAYS_BIRTH
#  11  DAYS_EMPLOYED
#  12  FLAG_MOBIL
#  13  FLAG_WORK_PHONE
#  14  FLAG_PHONE
#  15  FLAG_EMAIL
#  16  OCCUPATION_TYPE
#  17  CNT_FAM_MEMBERS
#
#
# C.   Summary: The dataset of a credit card application was viewed 18694, downloaded 3171 and download per view ratio 0.17 on Kaggle. The Range Index 690, entries 0 to 689. There are total 16 columns on the dataset.
#
# Features name with description
#  0   Gender
#  1   Age
#  2   Debt
#  3   Married
#  4   Bank Customer
#  5   Industry
#  6   Ethnicity
#  7   Years Employed
#  8   Prior Default
#  9   Employed
#  10. Credit Score
#  11. Driving License
#  12. Citizen
#  13. Zip Code
#  14. Income
#  15. Approved
#
#
#  D. Summary: The dataset of a credit card application was viewed 10810 , downloaded 1184 and download per view ratio 0.11 on Kaggle. The Range Index 537667, entries 0 to 537667. There are total 19 columns on the dataset.
#
# Features name with description:
#
# 0   ID: Unique id of users
#  1   CODE_GENDER: Male or female
#  2   FLAG_OWN_CAR: Numbers of cars or not
#  3   FLAG_OWN_REALTY:
#  4   CNT_CHILDREN: Number of children for nominee of users
#  5   AMT_INCOME_TOTAL: Amount of income yearly or monthly
#  6   NAME_EDUCATION_TYPE: Academic background
#  7   NAME_FAMILY_STATUS: Marital status of users.
#  8   NAME_HOUSING_TYPE: Living address of users
#  9   DAYS_BIRTH: Date of birth
#  10  DAYS_EMPLOYED: Since when he is in job
#  11  FLAG_MOBILE: Mobile number
#  12  FLAG_WORK_PHONE: Work place phone number
#  13  FLAG_PHONE : Phone number
#  14  FLAG_EMAIL: Email account
#  15  JOB: The work owner is doing
#  16  BEGIN_MONTHS: Since when owner in this job
#  17  STATUS: Marital status of users.
#
#
#
# E. The dataset of a credit card application was viewed 1828 , downloaded 1107 and download per view ratio 0.61 on Kaggle. The Range Index 500000, entries 0 to 499999. There are total 6 columns on the first dataset.
#
# Features name with description:
#
#  0   Num_Children: Number of children for nominee of users
#  1   Group:
#  2   Income: What is the income of the owner
#  3   Own_Car: How many vehicel owner have
#  4   Own_Housing: How many house owner have
#  5   Target: How many card owner will take

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 3. Read those datasets using python. Show the heads and tails. Use aavaialble python functions to describe those datasets in brief (how many null values, what are the data types, etc. Can you use a single function to show these info?).

# %%
# Your code below:
# Import pandas as pd
import pandas as pd

# Import the csv data:
a = pd.read_csv('/content/drive/MyDrive/303/CSV_file credit card application approval/A.csv')

# Print out head and tail
print(a)

# Print out all the info
print(a.info())
# Out:
#        Applicant_ID Applicant_Gender  Owned_Car  Owned_Realty  Total_Children  \
# 0           5008806          M                1             1               0
# 1           5008808          F                0             1               0
# 2           5008809          F                0             1               0
# 3           5008810          F                0             1               0
# 4           5008811          F                0             1               0
# ...             ...              ...        ...           ...             ...
# 25123       5150482          F                1             1               1
# 25124       5150483          F                1             1               1
# 25125       5150484          F                1             1               1
# 25126       5150485          F                1             1               1
# 25127       5150487          M                1             0               0
#
# ...

# %%
# Your code below:
# Import pandas as pd
import pandas as pd

# Import the csv data:
b = pd.read_csv('/content/drive/MyDrive/303/CSV_file credit card application approval/B.csv')

# Print out head and tail
print(b)

# Print out all the info
print(b.info())
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008805           M            Y               Y             0
# 2       5008806           M            Y               Y             0
# 3       5008808           F            N               Y             0
# 4       5008809           F            N               Y             0
# ...         ...         ...          ...             ...           ...
# 438552  6840104           M            N               Y             0
# 438553  6840222           F            N               N             0
# 438554  6841878           F            N               N             0
# 438555  6842765           F            N               Y             0
# 438556  6842885           F            N               Y             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
# Your code below:
# Import pandas as pd
import pandas as pd

# Import the csv data:
c = pd.read_csv('/content/drive/MyDrive/303/CSV_file credit card application approval/C.csv')

# Print out head and tail
print(c)

# Print out all the info
print(c.info())
# Out:
#      Gender    Age    Debt  Married  BankCustomer         Industry Ethnicity  \
# 0         1  30.83   0.000        1             1      Industrials     White
# 1         0  58.67   4.460        1             1        Materials     Black
# 2         0  24.50   0.500        1             1        Materials     Black
# 3         1  27.83   1.540        1             1      Industrials     White
# 4         1  20.17   5.625        1             1      Industrials     White
# ..      ...    ...     ...      ...           ...              ...       ...
# 685       1  21.08  10.085        0             0        Education     Black
# 686       0  22.67   0.750        1             1           Energy     White
# 687       0  25.25  13.500        0             0       Healthcare    Latino
# 688       1  17.92   0.205        1             1  ConsumerStaples     White
# 689       1  35.00   3.375        1             1           Energy     Black
#
# ...

# %%
# Your code below:
# Import pandas as pd
import pandas as pd

# Import the csv data:
d = pd.read_csv('/content/drive/MyDrive/303/CSV_file credit card application approval/D.csv')

# Print out head and tail
print(d)

# Print out all the info
print(d.info())
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY CNT_CHILDREN  \
# 0       5065438           F            Y               N  2+ children
# 1       5142753           F            N               N  No children
# 2       5111146           M            Y               Y  No children
# 3       5010310           F            Y               Y   1 children
# 4       5010835           M            Y               Y  2+ children
# ...         ...         ...          ...             ...          ...
# 537662  5142999           M            Y               N   1 children
# 537663  5010773           F            N               Y  No children
# 537664  5105601           M            N               Y  No children
# 537665  5132833           M            Y               N  No children
# 537666  5135381           F            N               Y  No children
#
#         AMT_INCOME_TOTAL            NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS  \
# ...

# %%
# Your code below:
# Import pandas as pd
import pandas as pd

# Import the csv data:
e = pd.read_csv('/content/drive/MyDrive/303/CSV_file credit card application approval/E.csv')

# Print out head and tail
print(e)

# Print out all the info
print(e.info())
# Out:
#         Num_Children  Group  Income  Own_Car  Own_Housing  Target
# 0                  4      0   36151        0            0       0
# 1                  0      0   36095        1            0       0
# 2                  2      1   62110        1            1       0
# 3                  0      1   73644        1            0       0
# 4                  3      0   99146        0            0       1
# ...              ...    ...     ...      ...          ...     ...
# 499995             1      0   43299        1            1       0
# 499996             8      1   75956        1            1       1
# 499997             3      0   66476        0            0       0
# 499998             2      1   74524        0            0       0
# 499999             4      0   31129        1            0       0
#
# [500000 rows x 6 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 6 columns):
# ...

# %% [markdown]
# ### 4. Find which research articles cited those datasets. For examople, cosider, there is a dataset named 'CASIA-1'. You have to find which reseach articles cited CASIA-1 and used that dataset in their research paper. Generally you can find this info from the dataset providers website and from google scholar search.

# %% [markdown]
# **The C dataset which original name is "crx.data" has been cited and used in:
#
# Xiaoming Huo. FBP: A Frontier-Based Tree-Pruning Algorithm. Seoung Bum Kim. 2002. [View Context].
#
# Lorne Mason and Peter L. Bartlett and Jonathan Baxter. Improved Generalization Through Explicit Optimization of Margins. Machine Learning, 38. 2000. [View Context].
#
# Kagan Tumer and Joydeep Ghosh. Robust Combining of Disparate Classifiers through Order Statistics. CoRR, csLG/9905013. 1999. [View Context].
#
# Lorne Mason and Peter L. Bartlett and Jonathan Baxter. Direct Optimization of Margins Improves Generalization in Combined Classifiers. NIPS. 1998. [View Context].

# %% [markdown]
# ### Is there any existing survey done on those datasets? Mention any relavent survey done on your topic (not only for datasets around your topic, but on Anything in general around your topic)

# %% [markdown]
# Your findings in this cell:
